# %%
import pyomo.environ as pe # Pyomo environment
from idaes.core import FlowsheetBlock, StateBlock
from idaes.unit_models import HeatExchanger
from idaes.unit_models.heat_exchanger import delta_temperature_amtd_callback
from idaes.property_models import iapws95

# Create an empty flowsheet and steam property parameter block.
model = pe.ConcreteModel()
model.fs = FlowsheetBlock(default={"dynamic": False})
model.fs.properties = iapws95.Iapws95ParameterBlock()

# Add a Heater model to the flowsheet.
model.fs.heat_exchanger = HeatExchanger(default={
        "delta_temperature_callback":delta_temperature_amtd_callback,
        "shell":{"property_package": model.fs.properties},
        "tube":{"property_package": model.fs.properties}})

model.fs.heat_exchanger.area.fix(1000)
model.fs.heat_exchanger.overall_heat_transfer_coefficient[0].fix(100)
model.fs.heat_exchanger.shell_inlet.flow_mol.fix(100)
model.fs.heat_exchanger.shell_inlet.pressure.fix(101325)
model.fs.heat_exchanger.shell_inlet.enth_mol.fix(4000)
model.fs.heat_exchanger.tube_inlet.flow_mol.fix(100)
model.fs.heat_exchanger.tube_inlet.pressure.fix(101325)
model.fs.heat_exchanger.tube_inlet.enth_mol.fix(3000)

# Initialize the model
model.fs.heat_exchanger.initialize()
# Out:
# 2020-04-27 18:14:20 - ERROR - idaes.property_models.iapws95 - IAPWS library file not found. Was it compiled?
# 2020-04-27 18:14:20 - ERROR - idaes.property_models.iapws95 - IAPWS library file not found. Was it compiled?
# 2020-04-27 18:14:20 - ERROR - idaes.property_models.iapws95 - IAPWS library file not found. Was it compiled?
# 2020-04-27 18:14:20 - ERROR - idaes.property_models.iapws95 - IAPWS library file not found. Was it compiled?
# 2020-04-27 18:14:20 - Level 5 - idaes.init.fs.heat_exchanger.side_1 - Initialization Complete
# 2020-04-27 18:14:20 - Level 5 - idaes.init.fs.heat_exchanger.side_2 - Initialization Complete
# ERROR: evaluating object as numeric value: func_tau((fs.heat_exchanger.side_1.
#     properties_in[0.0].enth_mol/fs.properties.mw/1000),
#     (0.001*fs.heat_exchanger.side_1.properties_in[0.0].pressure))
#         (object: <class
#         'pyomo.core.expr.numeric_expr.ExternalFunctionExpression'>)
#     dlopen(/Users/adlerlabadmin/.idaes/lib/iapws95_external.so, 6): image not
#     found
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/external.py in load_library(self)
#     139         try:
# --> 140             self._so = cdll.LoadLibrary(self._library)
#     141         except OSError:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/ctypes/__init__.py in LoadLibrary(self, name)
#     441     def LoadLibrary(self, name):
# --> 442         return self._dlltype(name)
#     443
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#
# OSError: dlopen(/Users/adlerlabadmin/.idaes/lib/iapws95_external.so, 6): image not found
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/external.py in load_library(self)
#     145             try:
# --> 146                 self._so = cdll.LoadLibrary(os.path.join('.',self._library))
#     147             except OSError:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/ctypes/__init__.py in LoadLibrary(self, name)
#     441     def LoadLibrary(self, name):
# --> 442         return self._dlltype(name)
#     443
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#
# OSError: dlopen(/Users/adlerlabadmin/.idaes/lib/iapws95_external.so, 6): image not found
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-802d9b70c8a1> in <module>
#      26
#      27 # Initialize the model
# ---> 28 model.fs.heat_exchanger.initialize()
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/heat_exchanger.py in initialize(self, state_args_1, state_args_2, outlvl, solver, optarg, duty)
#     447         self.heat_transfer_equation.deactivate()
#     448         self.side_2.heat.fix(duty)
# --> 449         results = opt.solve(self, tee=init_tee(init_log), symbolic_solver_labels=True)
#     450         init_log.log(
#     451             4, "Initialization Step 2 {}.".format(results.solver.termination_condition)
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/opt/base/solvers.py in solve(self, *args, **kwds)
#     571             initial_time = time.time()
#     572
# --> 573             self._presolve(*args, **kwds)
#     574
#     575             presolve_completion_time = time.time()
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/opt/solver/shellcmd.py in _presolve(self, *args, **kwds)
#     196         self._define_signal_handlers = kwds.pop('use_signal_handling',None)
#     197
# --> 198         OptSolver._presolve(self, *args, **kwds)
#     199
#     200         #
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/opt/base/solvers.py in _presolve(self, *args, **kwds)
#     671                                       self._problem_format,
#     672                                       self._valid_problem_formats,
# --> 673                                       **kwds)
#     674             total_time = time.time() - write_start_time
#     675             if self._report_timing:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/opt/base/solvers.py in _convert_problem(self, args, problem_format, valid_problem_formats, **kwds)
#     742                                valid_problem_formats,
#     743                                self.has_capability,
# --> 744                                **kwds)
#     745
#     746     def _default_results_format(self, prob_format):
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/opt/base/convert.py in convert_problem(args, target_problem_type, valid_problem_types, has_capability, **kwds)
#     103                     tmpkw = kwds
#     104                     tmpkw['capabilities'] = has_capability
# --> 105                     problem_files, symbol_map = converter.apply(*tmp, **tmpkw)
#     106                     return problem_files, ptype, symbol_map
#     107
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/solvers/plugins/converter/model.py in apply(self, *args, **kwds)
#     189                             format=args[1],
#     190                             solver_capability=capabilities,
# --> 191                             io_options=io_options)
#     192                 return (problem_filename,), symbol_map_id
#     193             else:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/block.py in write(self, filename, format, solver_capability, io_options)
#    1827                                           filename,
#    1828                                           solver_capability,
# -> 1829                                           io_options)
#    1830         smap_id = id(smap)
#    1831         if not hasattr(self, 'solutions'):
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/plugins/ampl/ampl_.py in __call__(self, model, filename, solver_capability, io_options)
#     374                     skip_trivial_constraints=skip_trivial_constraints,
#     375                     file_determinism=file_determinism,
# --> 376                     include_all_variable_bounds=include_all_variable_bounds)
#     377
#     378         self._symbolic_solver_labels = False
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/plugins/ampl/ampl_.py in _print_model_NL(self, model, solver_capability, show_section_timing, skip_trivial_constraints, file_determinism, include_all_variable_bounds)
#     962                     if gen_con_repn:
#     963                         repn = generate_standard_repn(constraint_data.body,
# --> 964                                                       quadratic=False)
#     965                         block_repn[constraint_data] = repn
#     966                         linear_vars = repn.linear_vars
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in generate_standard_repn(expr, idMap, compute_values, verbose, quadratic, repn)
#     384                                 verbose=verbose,
#     385                                 quadratic=quadratic,
# --> 386                                 repn=repn)
#     387
#     388 ##-----------------------------------------------------------------------
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _generate_standard_repn(expr, idMap, compute_values, verbose, quadratic, repn)
#     972         # This is the common case, so start collecting the sum
#     973         #
# --> 974         ans = _collect_sum(expr, 1, idMap, compute_values, verbose, quadratic)
#     975     else:
#     976         #
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_sum(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     485         else:
#     486             res_ = _collect_standard_repn(e_, multiplier, idMap,
# --> 487                                       compute_values, verbose, quadratic)
#     488             #
#     489             # Add returned from recursion
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_standard_repn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     944     fn = _repn_collectors.get(exp.__class__, None)
#     945     if fn is not None:
# --> 946         return fn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     947     #
#     948     # Catch any known numeric constants
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_negation(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     837
#     838 def _collect_negation(exp, multiplier, idMap, compute_values, verbose, quadratic):
# --> 839     return _collect_standard_repn(exp._args_[0], -1*multiplier, idMap, compute_values, verbose, quadratic)
#     840
#     841 #
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_standard_repn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     944     fn = _repn_collectors.get(exp.__class__, None)
#     945     if fn is not None:
# --> 946         return fn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     947     #
#     948     # Catch any known numeric constants
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_sum(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     485         else:
#     486             res_ = _collect_standard_repn(e_, multiplier, idMap,
# --> 487                                       compute_values, verbose, quadratic)
#     488             #
#     489             # Add returned from recursion
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_standard_repn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     944     fn = _repn_collectors.get(exp.__class__, None)
#     945     if fn is not None:
# --> 946         return fn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     947     #
#     948     # Catch any known numeric constants
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_identity(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     856         else:
#     857             return Results(constant=multiplier*exp._args_[0])
# --> 858     return _collect_standard_repn(exp.expr, multiplier, idMap, compute_values, verbose, quadratic)
#     859
#     860 def _collect_linear(exp, multiplier, idMap, compute_values, verbose, quadratic):
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_standard_repn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     944     fn = _repn_collectors.get(exp.__class__, None)
#     945     if fn is not None:
# --> 946         return fn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     947     #
#     948     # Catch any known numeric constants
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_division(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     768             denom = 1.0 * exp._args_[1]
#     769     else:
# --> 770         res =_collect_standard_repn(exp._args_[1], 1, idMap, compute_values, verbose, quadratic)
#     771         if not (res.nonl.__class__ in native_numeric_types and res.nonl == 0) or len(res.linear) > 0 or (quadratic and len(res.quadratic) > 0):
#     772             # Denominator is variable, give up: this is nonlinear
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_standard_repn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     944     fn = _repn_collectors.get(exp.__class__, None)
#     945     if fn is not None:
# --> 946         return fn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     947     #
#     948     # Catch any known numeric constants
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/repn/standard_repn.py in _collect_external_fn(exp, multiplier, idMap, compute_values, verbose, quadratic)
#     896 def _collect_external_fn(exp, multiplier, idMap, compute_values, verbose, quadratic):
#     897     if compute_values and exp.is_fixed():
# --> 898         return Results(nonl=multiplier*value(exp))
#     899     return Results(nonl=multiplier*exp)
#     900
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/expr/numvalue.py in value(obj, exception)
#     224
#     225         try:
# --> 226             tmp = obj(exception=True)
#     227             if tmp is None:
#     228                 raise ValueError(
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/expr/numeric_expr.py in __call__(self, exception)
#     221             The value of the expression or :const:`None`.
#     222         """
# --> 223         return evaluate_expression(self, exception)
#     224
#     225     def __str__(self):
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/expr/visitor.py in evaluate_expression(exp, exception, constant)
#     972         visitor = _EvaluationVisitor()
#     973     try:
# --> 974         return visitor.dfs_postorder_stack(exp)
#     975
#     976     except NonConstantExpressionError:  #pragma: no cover
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/expr/visitor.py in dfs_postorder_stack(self, node)
#     534             # Process the current node
#     535             #
# --> 536             ans = self.visit(_obj, _result)
#     537             if _stack:
#     538                 #
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/expr/visitor.py in visit(self, node, values)
#     880     def visit(self, node, values):
#     881         """ Visit nodes that have been expanded """
# --> 882         return node._apply_operation(values)
#     883
#     884     def visiting_potential_leaf(self, node):
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/expr/numeric_expr.py in _apply_operation(self, result)
#     636
#     637     def _apply_operation(self, result):
# --> 638         return self._fcn.evaluate( result )
#     639
#     640     def _to_string(self, values, verbose, smap, compute_values):
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/external.py in evaluate(self, args)
#     124
#     125     def evaluate(self, args):
# --> 126         return self._evaluate(args, 0, None)[0]
#     127
#     128     def evaluate_fgh(self, args, fixed=None):
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/external.py in _evaluate(self, args, fgh, fixed)
#     104     def _evaluate(self, args, fgh, fixed):
#     105         if self._so is None:
# --> 106             self.load_library()
#     107         if self._function not in self._known_functions:
#     108             raise RuntimeError(
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/external.py in load_library(self)
#     148                 # Re-try with the original library name and allow the
#     149                 # exception to propagate up.
# --> 150                 self._so = cdll.LoadLibrary(self._library)
#     151
#     152         self._known_functions = {}
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/ctypes/__init__.py in LoadLibrary(self, name)
#     440
#     441     def LoadLibrary(self, name):
# --> 442         return self._dlltype(name)
#     443
#     444 cdll = LibraryLoader(CDLL)
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#     366             self._handle = handle
#
# OSError: dlopen(/Users/adlerlabadmin/.idaes/lib/iapws95_external.so, 6): image not found
