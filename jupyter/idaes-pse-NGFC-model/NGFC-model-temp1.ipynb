# %% [markdown]
# # NGFC Modelling with IDEAS - pse
# This is a modelling example of a NGFC system using idaes-pse framework.

# %%
from pyomo.environ import ConcreteModel, Constraint, Objective, SolverFactory, TransformationFactory, Constraint, Var
from pyomo.network import Arc

# %%
from idaes.core import FlowsheetBlock
from idaes.unit_models import Mixer, HeatExchanger, Separator, GibbsReactor, Heater
# Methane combustion ideal package got CH4, H2O, CO, CO2, N2, NH3, O2
import idaes.property_models.activity_coeff_models.methane_combustion_ideal as thermo_props
#import idaes.property_models.activity_coeff_models.methane_combustion_ideal as reaction_props

# %%
import matplotlib.pyplot as plt

# %%
from idaes.unit_models.separator import SplittingType
from idaes.unit_models.heat_exchanger import delta_temperature_amtd_callback
from idaes.core.util.model_statistics import degrees_of_freedom as dof

# %% [markdown]
# ### Building Base Flowsheet.

# %%
m = ConcreteModel()
m.fs = FlowsheetBlock(default={"dynamic": False})
m.fs.thermo_params = thermo_props.MethaneParameterBlock()

# %%
# Fuel ultilization (Uf): mole reductant consumed in FC per mole of reductant total
Uf = 0.8
# Air ultilization (Ua): mole of air consumed in FC per mole of air feed
Ua = 0.2
# Methane to steam ratio (MS): mole methane per mole water
MS = 2
# Feed:
# Reaction: 
# Reforming: CH4 + H2O -> CO + 3H2
# Water gas shift: CO + H2O -> CO2 + H2
# Methane combustion: CH4 + 2O2 -> CO2 + 2H2O
# Hydrogen combustion: H2 + 1/2O2 -> H2O
# Carbon monoxide combustion: CO + 1/2O2 -> CO2

n_CH4f = 10
print("mole of methane feed: "+str(n_CH4f)+" mole/s")
n_H2Of = n_CH4f*MS
print("mole of steam feed: "+str(n_H2Of)+" mole/s")
n_O2f = n_CH4f*Uf*2/Ua
n_N2f = n_O2f*0.79/0.21
print("mole of air feed: "+str(n_N2f+n_O2f)+" mole/s")

n_H2ex = 2
n_COex = n_CH4f*(1-Uf)*4-n_H2ex
n_CO2ex = n_CH4f-n_COex
n_H2Oex = n_H2Of+2*n_CH4f-n_H2ex
y_H2ex = n_H2ex/(n_H2ex + n_COex + n_CO2ex + n_H2Oex)
y_COex = n_COex/(n_H2ex + n_COex + n_CO2ex + n_H2Oex)
y_CO2ex = n_CO2ex/(n_H2ex + n_COex + n_CO2ex + n_H2Oex)
y_H2Oex = n_H2Oex/(n_H2ex + n_COex + n_CO2ex + n_H2Oex)

print("Anode exhaust: ")
print("y_H2ex: "+str(y_H2ex))
print("y_COex: "+str(y_COex))
print("y_CO2ex: "+str(y_CO2ex))
print("y_H2Oex: "+str(y_H2Oex))
print("Total mole/s: "+str(n_H2ex + n_COex + n_CO2ex + n_H2Oex))

n_N2ex = n_N2f
n_O2ex = n_O2f - n_CH4f*Uf*2
y_O2ex = n_O2ex/(n_O2ex+n_N2ex)
y_N2ex = n_N2ex/(n_O2ex+n_N2ex)
print("Cathode exhaust: ")
print("y_O2ex: "+str(y_O2ex))
print("y_N2ex: "+str(y_N2ex))
print("Total mole/s: "+str(n_O2ex+n_N2ex))
# Out:
# mole of methane feed: 10 mole/s
# mole of steam feed: 20 mole/s
# mole of air feed: 380.95238095238096 mole/s
# Anode exhaust:
# y_H2ex: 0.04
# y_COex: 0.11999999999999997
# y_CO2ex: 0.08000000000000003
# y_H2Oex: 0.76
# Total mole/s: 50.0
# Cathode exhaust:
# y_O2ex: 0.1753653444676409
# y_N2ex: 0.824634655532359
# Total mole/s: 364.95238095238096

# %%
# Temperature User input
T_FC_air_in = 700 + 273.15
T_FC_fuel_in = 400 + 273.15
T_FC_ex_out = 800 + 273.15

# %% [markdown]
# ### Declare all Units:

# %%
m.fs.HX1 = HeatExchanger(default={"dynamic": False,
                                  "delta_temperature_callback": delta_temperature_amtd_callback,
                                  "shell":{"property_package": m.fs.thermo_params},
                                  "tube":{"property_package": m.fs.thermo_params}})

# %%
m.fs.HX2 = HeatExchanger(default={"dynamic": False,
                                  "delta_temperature_callback": delta_temperature_amtd_callback,
                                  "shell":{"property_package": m.fs.thermo_params},
                                  "tube":{"property_package": m.fs.thermo_params}})

# %%
m.fs.HX3 = HeatExchanger(default={"dynamic": False,
                                  "delta_temperature_callback": delta_temperature_amtd_callback,
                                  "shell":{"property_package": m.fs.thermo_params},
                                  "tube":{"property_package": m.fs.thermo_params}})

# %%
m.fs.Heater = Heater(default={"property_package": m.fs.thermo_params})

# %%
m.fs.Mix1 = Mixer(default={"dynamic": False,
                           "property_package": m.fs.thermo_params})

# %%
m.fs.Mix2 = Mixer(default={"dynamic": False,
                           "property_package": m.fs.thermo_params})

# %%
m.fs.Mix3 = Mixer(default={"dynamic": False,
                           "property_package": m.fs.thermo_params})

# %%
m.fs.Mix4 = Mixer(default={"dynamic": False,
                           "num_inlets": 3,
                           "property_package": m.fs.thermo_params})

# %%
m.fs.Split1 = Separator(default={"dynamic": False,
                                 "split_basis": SplittingType.componentFlow,
                                 "property_package": m.fs.thermo_params})

# %%
m.fs.Split2 = Separator(default={"dynamic": False,
                                 "num_outlets": 3,
                                 "split_basis": SplittingType.totalFlow,
                                 "property_package": m.fs.thermo_params})

# %%
m.fs.Reformer = GibbsReactor(default={"dynamic": False,
                                      "property_package": m.fs.thermo_params,
                                      "has_pressure_change": False,
                                      "has_heat_transfer": True})

# %%
m.fs.SOFC = GibbsReactor(default={"dynamic": False,
                                  "property_package": m.fs.thermo_params,
                                  "has_pressure_change": False,
                                  "has_heat_transfer": True})

# %%
m.fs.Burner = GibbsReactor(default={"dynamic": False,
                                    "property_package": m.fs.thermo_params,
                                    "has_pressure_change": False,
                                    "has_heat_transfer": True})

# %% [markdown]
# ### Declare all Streams:

# %%
m.fs.stream0 = Arc(source=m.fs.Mix1.outlet,
                   destination=m.fs.HX1.tube_inlet)

# %%
m.fs.stream1 = Arc(source=m.fs.Split1.outlet_1,
                   destination=m.fs.HX3.tube_inlet)

# %%
m.fs.stream2 = Arc(source=m.fs.HX1.tube_outlet,
                   destination=m.fs.Reformer.inlet)

# %%
m.fs.stream3 = Arc(source=m.fs.Split1.outlet_2,
                   destination=m.fs.HX2.tube_inlet)

# %%
m.fs.stream4 = Arc(source=m.fs.Reformer.outlet,
                   destination=m.fs.Mix2.inlet_1)

# %%
m.fs.stream5 = Arc(source=m.fs.HX3.tube_outlet,
                   destination=m.fs.Mix2.inlet_2)

# %%
m.fs.stream6 = Arc(source=m.fs.Mix2.outlet,
                   destination=m.fs.SOFC.inlet)

# %%
m.fs.stream7 = Arc(source=m.fs.HX2.tube_outlet,
                   destination=m.fs.Mix3.inlet_2)

# %%
m.fs.stream8 = Arc(source=m.fs.SOFC.outlet,
                   destination=m.fs.Mix3.inlet_1)

# %%
m.fs.stream9 = Arc(source=m.fs.Mix3.outlet,
                   destination=m.fs.Burner.inlet)

# %%
m.fs.stream10 = Arc(source=m.fs.Burner.outlet,
                    destination=m.fs.Split2.inlet)

# %%
m.fs.stream11 = Arc(source=m.fs.Split2.outlet_1,
                    destination=m.fs.HX1.shell_inlet)

# %%
m.fs.stream12 = Arc(source=m.fs.Split2.outlet_2,
                    destination=m.fs.HX2.shell_inlet)

# %%
m.fs.stream13 = Arc(source=m.fs.Split2.outlet_3,
                    destination=m.fs.HX3.shell_inlet)

# %%
m.fs.stream14 = Arc(source=m.fs.HX1.shell_outlet,
                    destination=m.fs.Mix4.inlet_1)

# %%
m.fs.stream150 = Arc(source=m.fs.HX2.shell_outlet,
                     destination=m.fs.Heater.inlet)

# %%
m.fs.stream15 = Arc(source=m.fs.Heater.outlet,
                    destination=m.fs.Mix4.inlet_2)

# %%
m.fs.stream16 = Arc(source=m.fs.HX3.shell_outlet,
                    destination=m.fs.Mix4.inlet_3)

# %%
TransformationFactory("network.expand_arcs").apply_to(m)

# %% [markdown]
# ### Define known Material Streams:

# %%
# Fix methane flow to Mix1:
m.fs.Mix1.inlet_1.flow_mol.fix(n_CH4f)
m.fs.Mix1.inlet_1.mole_frac_comp[0.0,:].fix(0.0)
m.fs.Mix1.inlet_1.mole_frac_comp[0.0,"CH4"].fix(1.0)
m.fs.Mix1.inlet_1.temperature.fix(25+273.15)
m.fs.Mix1.inlet_1.pressure.fix(101325)

# %%
# Fix water flow to Mix1:
m.fs.Mix1.inlet_2.flow_mol.fix(n_H2Of)
m.fs.Mix1.inlet_2.mole_frac_comp[0.0,:].fix(0.0)
m.fs.Mix1.inlet_2.mole_frac_comp[0.0,"H2O"].fix(1.0)
m.fs.Mix1.inlet_2.temperature.fix(25+273.15)
m.fs.Mix1.inlet_2.pressure.fix(101325)

# %%
# Fix air flow to Split1:
m.fs.Split1.inlet.flow_mol.fix(n_N2f+n_O2f)
m.fs.Split1.inlet.mole_frac_comp[0.0,:].fix(0.0)
m.fs.Split1.inlet.mole_frac_comp[0.0,"O2"].fix(0.21)
m.fs.Split1.inlet.mole_frac_comp[0.0,"N2"].fix(0.79)
m.fs.Split1.inlet.temperature.fix(25+273.15)
m.fs.Split1.inlet.pressure.fix(101325)

# %%
# Fix O2 flow in Split1 outlet_1:
m.fs.Split1.outlet_1.flow_mol.fix(n_CH4f*Uf*2)
m.fs.Split1.outlet_1.mole_frac_comp[0.0,"CH4"].fix(0.0)
m.fs.Split1.outlet_1.mole_frac_comp[0.0,"CO"].fix(0.0)
m.fs.Split1.outlet_1.mole_frac_comp[0.0,"CO2"].fix(0.0)
m.fs.Split1.outlet_1.mole_frac_comp[0.0,"H2"].fix(0.0)
m.fs.Split1.outlet_1.mole_frac_comp[0.0,"H2O"].fix(0.0)
m.fs.Split1.outlet_1.mole_frac_comp[0.0,"N2"].fix(0.0)
m.fs.Split1.outlet_1.mole_frac_comp[0.0,"O2"].fix(1.0)

# %% [markdown]
# ### Constraints:  Adiabatic Burner

# %%
m.fs.Burner.heat_duty.fix(0.0)

# %%
m.fs.Reformer.heat_duty.fix(0.0)

# %% [markdown]
# ### Constraints: Reformer temperature

# %%
m.fs.Reformer.outlet.temperature.fix(T_FC_fuel_in)
print(T_FC_fuel_in-273.15)
# Out:
# 400.0

# %% [markdown]
# ### Constraints: SOFC exit temperature

# %%
m.fs.SOFC.outlet.temperature.fix(T_FC_ex_out)
print(T_FC_ex_out-273.15)
# Out:
# 800.0000000000001

# %% [markdown]
# ### Constraints: Heat Exchanger tube outlet temperature

# %%
m.fs.HX2.tube_outlet.temperature.fix(T_FC_ex_out)
print(T_FC_ex_out-273.15)
# Out:
# 800.0000000000001

# %%
m.fs.HX3.tube_outlet.temperature.fix(T_FC_air_in)
print(T_FC_air_in-273.15)
# Out:
# 700.0

# %% [markdown]
# ### Constraints: Heat duty in Heater

# %%
m.fs.Heater.heat_duty.fix(-n_H2Of*43988)

# %%
m.fs.Heater.heat_duty.display()
# Out:
# heat_duty : Size=1, Index=fs.time
#     Key : Lower : Value   : Upper : Fixed : Stale : Domain
#     0.0 :  None : -879760 :  None :  True : False :  Reals

# %% [markdown]
# ### Constraints: Heat Exchangers

# %%
m.fs.HX1.area.fix(500)

# %%
m.fs.HX2.area.fix(500)

# %%
m.fs.HX3.area.fix(500)

# %%
m.fs.HX1.shell_outlet.temperature.fix(120+273.15)

# %%
m.fs.HX3.shell_outlet.temperature.fix(120+273.15)

# %%
m.fs.Split2.split_fraction[0.0, "outlet_1"].fix(0.2)

# %%
m.fs.Split2.split_fraction.display()

# %%
m.fs.Split2.split_fraction[0.0, "outlet_2"].fix(0.8)

# %%
m.fs.HX1.overall_heat_transfer_coefficient.fix()

# %% [markdown]
# ### Constraints: HX1 delta temperature in (T_stream11 - T_stream2)

# %%
m.fs.HX1.delta_temperature_in.fix(30)

# %%
m.fs.HX1.delta_temperature_out.fix(250)

# %% [markdown]
# ### Constraints: HX2 delta temperature in (T_stream15 - T_stream3)

# %%
m.fs.HX2.delta_temperature_out.fix(20)

# %% [markdown]
# ### Constraints: HX3 delta temperature

# %%
m.fs.HX3.delta_temperature_out.fix(60)

# %% [markdown]
# ### Constraints: Split2 first fraction

# %%
m.fs.SOFC.heat_duty.fix(6040000)

# %%
dof(m.fs.HX2)

# %%
m.fs.Split2.split_fraction.display()

# %%
m.fs.Mix1.outlet.display()

# %%
dof(m)
# Out:
# 0

# %% [markdown]
# ## Initialize Stuff

# %%
m.fs.Mix1.initialize()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-3c6db407161c>", line 1, in <module>
#     m.fs.Mix1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-3c6db407161c>", line 1, in <module>
#     m.fs.Mix1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-3c6db407161c>", line 1, in <module>
#     m.fs.Mix1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 766, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-05-18 22:16:42 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix1.mixed_state State Released.
# 2020-05-18 22:16:42 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix1.inlet_1_state State Released.
# 2020-05-18 22:16:42 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix1.inlet_2_state State Released.

# %%
m.fs.Mix2.initialize()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-59-52d1908109b1>", line 1, in <module>
#     m.fs.Mix2.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-59-52d1908109b1>", line 1, in <module>
#     m.fs.Mix2.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-59-52d1908109b1>", line 1, in <module>
#     m.fs.Mix2.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 766, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-05-18 22:17:02 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix2.mixed_state State Released.
# 2020-05-18 22:17:02 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix2.inlet_1_state State Released.
# 2020-05-18 22:17:02 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix2.inlet_2_state State Released.

# %%
m.fs.Mix3.initialize()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-60-2e48294311d0>", line 1, in <module>
#     m.fs.Mix3.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-60-2e48294311d0>", line 1, in <module>
#     m.fs.Mix3.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-60-2e48294311d0>", line 1, in <module>
#     m.fs.Mix3.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 766, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-05-18 22:17:45 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix3.mixed_state State Released.
# 2020-05-18 22:17:45 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix3.inlet_1_state State Released.
# 2020-05-18 22:17:45 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix3.inlet_2_state State Released.

# %%
m.fs.Mix4.initialize()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-61-d590249d6be2>", line 1, in <module>
#     m.fs.Mix4.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-61-d590249d6be2>", line 1, in <module>
#     m.fs.Mix4.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-61-d590249d6be2>", line 1, in <module>
#     m.fs.Mix4.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-61-d590249d6be2>", line 1, in <module>
#     m.fs.Mix4.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 766, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-05-18 22:17:56 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.mixed_state State Released.
# 2020-05-18 22:17:56 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.inlet_1_state State Released.
# 2020-05-18 22:17:56 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.inlet_2_state State Released.
# 2020-05-18 22:17:56 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.inlet_3_state State Released.

# %%
m.fs.Split1.initialize()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-62-ac88044bf8d4>", line 1, in <module>
#     m.fs.Split1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py", line 1151, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-62-ac88044bf8d4>", line 1, in <module>
#     m.fs.Split1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py", line 1212, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-05-18 22:18:22 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Split1.outlet_1_state State Released.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py in initialize(blk, outlvl, optarg, solver, hold_state)
#    1186                                             m_var[k] *
# -> 1187                                             blk.split_fraction[(t, o)]))
#    1188                                     else:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/indexed_component.py in __getitem__(self, index)
#     406                 return index
# --> 407             validated_index = self._validate_index(index)
#     408             if validated_index is not index:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/indexed_component.py in _validate_index(self, idx)
#     566             "Index '%s' is not valid for indexed component '%s'"
# --> 567             % ( idx, self.name, ))
#     568
#
# KeyError: "Index '(0.0, 'outlet_2')' is not valid for indexed component 'fs.Split1.split_fraction'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-ac88044bf8d4> in <module>
# ----> 1 m.fs.Split1.initialize()
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py in initialize(blk, outlvl, optarg, solver, hold_state)
#    1201                                         "other cases users will need to "
#    1202                                         "provide their own initial guesses"
# -> 1203                                         .format(blk.name))
#    1204                             else:
#    1205                                 # Otherwise intensive, equate to mixed stream
#
# KeyError: 'fs.Split1 state variable and split fraction indexing sets do not match. The in-built  initialization routine for Separators relies on the split fraction and state variable indexing sets matching to calculate initial guesses for extensive variables. In other cases users will need to provide their own initial guesses'

# %%
m.fs.Mix1.initialize()
m.fs.Mix2.initialize()
m.fs.Mix4.initialize()
m.fs.Split2.initialize()
m.fs.HX1.initialize()
m.fs.HX2.initialize()
m.fs.HX3.initialize()
m.fs.Heater.initialize()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 1, in <module>
#     m.fs.Mix1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 1, in <module>
#     m.fs.Mix1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 1, in <module>
#     m.fs.Mix1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 766, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-04-28 10:42:55 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix1.mixed_state State Released.
# 2020-04-28 10:42:55 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix1.inlet_1_state State Released.
# 2020-04-28 10:42:55 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix1.inlet_2_state State Released.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 2, in <module>
#     m.fs.Mix2.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 2, in <module>
#     m.fs.Mix2.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 2, in <module>
#     m.fs.Mix2.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 766, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-04-28 10:42:56 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix2.mixed_state State Released.
# 2020-04-28 10:42:56 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix2.inlet_1_state State Released.
# 2020-04-28 10:42:56 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix2.inlet_2_state State Released.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 3, in <module>
#     m.fs.Mix3.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 3, in <module>
#     m.fs.Mix3.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 717, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
# ...
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 4, in <module>
#     m.fs.Mix4.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/mixer.py", line 766, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-04-28 10:42:57 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.mixed_state State Released.
# 2020-04-28 10:42:57 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.inlet_1_state State Released.
# 2020-04-28 10:42:57 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.inlet_2_state State Released.
# 2020-04-28 10:42:58 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Mix4.inlet_3_state State Released.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 5, in <module>
#     m.fs.Split1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py", line 1151, in initialize
#     hold_state=True)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-58-850e3c38c09c>", line 5, in <module>
#     m.fs.Split1.initialize()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py", line 1212, in initialize
#     hold_state=False)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# 2020-04-28 10:42:58 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.Split1.outlet_1_state State Released.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py in initialize(blk, outlvl, optarg, solver, hold_state)
#    1186                                             m_var[k] *
# -> 1187                                             blk.split_fraction[(t, o)]))
#    1188                                     else:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/indexed_component.py in __getitem__(self, index)
#     406                 return index
# --> 407             validated_index = self._validate_index(index)
#     408             if validated_index is not index:
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/indexed_component.py in _validate_index(self, idx)
#     566             "Index '%s' is not valid for indexed component '%s'"
# --> 567             % ( idx, self.name, ))
#     568
#
# KeyError: "Index '(0.0, 'outlet_2')' is not valid for indexed component 'fs.Split1.split_fraction'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-850e3c38c09c> in <module>
#       3 m.fs.Mix3.initialize()
#       4 m.fs.Mix4.initialize()
# ----> 5 m.fs.Split1.initialize()
#       6 m.fs.Split2.initialize()
#       7 m.fs.HX1.initialize()
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/separator.py in initialize(blk, outlvl, optarg, solver, hold_state)
#    1201                                         "other cases users will need to "
#    1202                                         "provide their own initial guesses"
# -> 1203                                         .format(blk.name))
#    1204                             else:
#    1205                                 # Otherwise intensive, equate to mixed stream
#
# KeyError: 'fs.Split1 state variable and split fraction indexing sets do not match. The in-built  initialization routine for Separators relies on the split fraction and state variable indexing sets matching to calculate initial guesses for extensive variables. In other cases users will need to provide their own initial guesses'

# %%
m.fs.Split2.split_fraction.display()

# %%
solver = SolverFactory('ipopt')

# %%
results = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     3991
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1067
#
# Total number of variables............................:     1154
#                      variables with only lower bounds:      107
#                 variables with lower and upper bounds:      609
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1154
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.56e+05 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 4.55e+05 2.21e+02  -1.0 4.06e+07    -  2.68e-04 1.28e-03h  1
#    2  0.0000000e+00 4.55e+05 6.18e+05  -1.0 4.35e+08    -  3.78e-05 6.41e-05h  1
#    3  0.0000000e+00 4.55e+05 5.85e+07  -1.0 8.84e+09    -  5.42e-08 2.65e-06f  2
#    4  0.0000000e+00 4.55e+05 5.78e+07  -1.0 6.09e+11    -  3.85e-08 3.85e-08s  2
#    5r 0.0000000e+00 4.55e+05 9.99e+02   5.7 0.00e+00    -  0.00e+00 0.00e+00R  1
#    6r 0.0000000e+00 4.55e+05 2.95e+05   5.7 3.11e+06    -  7.82e-04 8.45e-07f  1
#    7r 0.0000000e+00 4.51e+05 2.99e+05   3.6 3.05e+06    -  3.75e-03 1.56e-02f  1
#    8r 0.0000000e+00 4.51e+05 2.98e+05   3.6 1.88e+07    -  1.82e-03 2.00e-03f  1
#    9r 0.0000000e+00 4.51e+05 2.90e+05   3.6 4.15e+06    -  1.93e-02 3.00e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 4.50e+05 3.01e+05   3.6 8.73e+05    -  8.82e-02 1.60e-02f  1
#   11r 0.0000000e+00 4.50e+05 3.00e+05   3.6 7.14e+05    -  8.63e-02 3.77e-02f  1
#   12r 0.0000000e+00 4.50e+05 2.90e+05   3.6 6.53e+05    -  3.69e-02 4.22e-02f  1
#   13r 0.0000000e+00 4.49e+05 2.77e+05   2.9 4.81e+05    -  4.87e-02 2.61e-02f  1
#   14r 0.0000000e+00 4.49e+05 2.67e+05   2.9 7.25e+05    -  4.05e-02 4.02e-02f  1
#   15r 0.0000000e+00 4.48e+05 2.56e+05   2.9 4.86e+05    -  4.32e-02 4.07e-02f  1
#  226r 0.0000000e+00 6.03e+02 1.96e+03  -6.9 2.31e+05  -3.9 4.00e-10 8.51e-04f  1
#  227r 0.0000000e+00 6.03e+02 1.96e+03  -6.9 1.04e+05  -3.5 6.59e-03 8.82e-04f  1
#  228r 0.0000000e+00 6.03e+02 1.96e+03  -6.9 1.07e+05  -4.0 1.55e-03 1.60e-03f  1
#  229r 0.0000000e+00 6.03e+02 1.95e+03  -6.9 2.29e+04  -3.5 2.95e-01 1.53e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230r 0.0000000e+00 6.03e+02 1.95e+03  -6.9 9.44e+04  -4.0 4.50e-03 3.56e-10f  1
#  231r 0.0000000e+00 6.03e+02 1.88e+03  -6.9 4.63e+04  -4.5 7.70e-01 1.87e-03f  1
#  232r 0.0000000e+00 6.01e+02 1.88e+03  -6.9 1.29e+05  -5.0 4.93e-03 1.43e-02f  1
#  233r 0.0000000e+00 6.01e+02 1.88e+03  -6.9 1.36e+07    -  0.00e+00 4.09e-07R  4
# Restoration phase is called at point that is almost feasible,
#   with constraint violation 0.000000e+00. Abort.
# Restoration phase in the restoration phase failed.
#
# Number of Iterations....: 233
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   1.8847994581168625e+03    1.8847994581168625e+03
# Constraint violation....:   6.0051926760932690e+02    6.0051926760932690e+02
# Complementarity.........:   1.6141585259112996e-05    1.6141585259112996e-05
# Overall NLP error.......:   6.0051926760932690e+02    1.8847994581168625e+03
#
#
# Number of objective function evaluations             = 249
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 251
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 239
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 234
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.514
# Total CPU secs in NLP function evaluations           =      0.081
#
# EXIT: Restoration Failed!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-e70dd75abefd> in <module>
# ----> 1 results = solver.solve(m, tee=True)
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/opt/base/solvers.py in solve(self, *args, **kwds)
#     631                             result,
#     632                             select=self._select_index,
# --> 633                             default_variable_value=self._default_variable_value)
#     634                         result._smap_id = None
#     635                         result.solution.clear()
#
# ~/anaconda3/envs/idaes-env/lib/python3.7/site-packages/pyomo/core/base/PyomoModel.py in load_from(self, results, allow_consistent_values_for_fixed_vars, comparison_tolerance_for_fixed_vars, ignore_invalid_labels, id, delete_symbol_map, clear, default_variable_value, select, ignore_fixed_vars)
#     240                 raise ValueError("Cannot load a SolverResults object "
#     241                                  "with bad status: %s"
# --> 242                                  % str(results.solver.status))
#     243         if clear:
#     244             #
#
# ValueError: Cannot load a SolverResults object with bad status: error

# %%
print(results)

# %%
m.fs.Reformer.display()

# %%
m.fs.HX2.display()

# %%
m.fs.Mix4.inlet_1.display()

# %%
m.fs.Mix4.inlet_2.display()

# %%
m.fs.Mix4.inlet_3.display()

# %%
m.fs.Burner.outlet.display()

# %%
m.fs.SOFC.heat_duty.display()

# %%
m.fs.Split2.split_fraction.display()

# %%
m.fs.HX1.inlet_1.display()

# %%
m.fs.HX1.tube_inlet.display()

# %%
m.fs.Mix1.inlet_1.display()

# %%
m.fs.Mix1.inlet_2.display()

# %%
m.fs.Mix1.outlet.display()

# %%
m.fs.Heater.display()

# %%
m.fs.Mix4.inlet_1.display()

# %%
354.9024586155912-273.15

# %% [markdown]
# ### First mixer (Mix1) combines methane and water stream:

# %%
m.fs.mix1 = Mixer(default={"dynamic": False,
                           "property_package": m.fs.thermo_params})

# %%
m.fs.mix1.inlet_1.flow_mol.fix(n_CH4f)
m.fs.mix1.inlet_1.mole_frac_comp[0.0,:].fix(0.0)
m.fs.mix1.inlet_1.mole_frac_comp[0.0,"CH4"].fix(1.0)
m.fs.mix1.inlet_1.temperature.fix(25+273.15)
m.fs.mix1.inlet_1.pressure.fix(101325)

# %%
m.fs.mix1.inlet_2.flow_mol.fix(n_H2Of)
m.fs.mix1.inlet_2.mole_frac_comp[0.0,:].fix(0.0)
m.fs.mix1.inlet_2.mole_frac_comp[0.0,"H2O"].fix(1.0)
m.fs.mix1.inlet_2.temperature.fix(25+273.15)
m.fs.mix1.inlet_2.pressure.fix(101325)

# %%
m.fs.mix1.inlet_1.display()

# %%
m.fs.mix1.inlet_2.display()

# %% [markdown]
# ### First heat exchanger (HX1) heats up methane & water stream
# ### Also reformer (Reformer) is a Gibbs Reactor that receive heat from HX1 exhaust stream

# %%
# Set up reformer?
m.fs.reformer = GibbsReactor(default={"dynamic": False,
                                      "property_package": m.fs.thermo_params,
                                      "has_pressure_change": False,
                                      "has_heat_transfer": True})

# %%
m.fs.stream1 = Arc(source=m.fs.mix1.outlet,
                   destination=m.fs.reformer.inlet)

# %%
m.fs.reformer.outlet.temperature.fix(T_FC_fuel_in+273.15)

# %% [markdown]
# ### HX1: Provide the heat duty for Reformer

# %% [markdown]
# ### Seperator (Sep1) split the air into a single of stream of O2 going to SOFC

# %% [markdown]
# ### Mix2: combined reformer outlet stream and O2 stream from cathode.

# %%
m.fs.mix2 = Mixer(default={"dynamic": False,
                           "property_package": m.fs.thermo_params})

# %%
m.fs.stream2 = Arc(source=m.fs.reformer.outlet,
                   destination=m.fs.mix2.inlet_1)

# %%
m.fs.mix2.inlet_2.flow_mol.fix(n_CH4f*Uf*2)
m.fs.mix2.inlet_2.mole_frac_comp[0.0,:].fix(0.0)
m.fs.mix2.inlet_2.mole_frac_comp[0.0,"O2"].fix(1.0)
m.fs.mix2.inlet_2.temperature.fix(T_FC_air_in+273.15)
m.fs.mix2.inlet_2.pressure.fix(101325)

# %% [markdown]
# ### SOFC: Gibbs Reactor w stream coming from mix2

# %%
# Set up SOFC
m.fs.SOFC = GibbsReactor(default={"dynamic": False,
                                  "property_package": m.fs.thermo_params,
                                  "has_pressure_change": False,
                                  "has_heat_transfer": True})

# %%
m.fs.stream3 = Arc(source=m.fs.mix2.outlet,
                   destination=m.fs.SOFC.inlet)

# %%
m.fs.SOFC.outlet.temperature.fix(T_FC_ex_out+273.15)

# %%
m.fs.mix1.initialize()

# %%
m.fs.mix2.initialize()

# %% [markdown]
# ### SOFC outlet come into the burner with the rest of the air
# ### Burner: Gibbs Reactor

# %%
# Feed to the burner

# %%
TransformationFactory("network.expand_arcs").apply_to(m)

# %%
m.fs.reformer.inlet.display()

# %%
m.fs.reformer.outlet.display()

# %%
m.fs.reformer.heat_duty.display()

# %%
m.fs.mix2.inlet_1.display()

# %%
m.fs.mix2.inlet_2.display()

# %%
m.fs.mix2.outlet.display()

# %%
m.fs.SOFC.inlet.display()

# %%
m.fs.SOFC.outlet.display()

# %%
m.fs.SOFC.heat_duty.display()

# %%
m.fs.burner = GibbsReactor(default={"dynamic": False,
                                    "property_package": m.fs.thermo_params,
                                    "has_pressure_change": False,
                                    "has_heat_transfer": True})

# %% [markdown]
# ### SOFC: Gibbs Reactor, taking Reformer outlet and a specified O2 amount from Mix2

# %% [markdown]
# ### Mixing anode & cathode exhaust:

# %%
m.fs.mix_exhaust = Mixer(default={"dynamic": False,
                                  "property_package": m.fs.thermo_params})

# %%
# First inlet to mix_exhaust : anode exhaust
m.fs.mix_exhaust.inlet_1.flow_mol.fix(50.0)
m.fs.mix_exhaust.inlet_1.mole_frac_comp[0.0,:].fix(0.0)
m.fs.mix_exhaust.inlet_1.mole_frac_comp[0.0,"H2"].fix(0.04)
m.fs.mix_exhaust.inlet_1.mole_frac_comp[0.0,"CO"].fix(0.12)
m.fs.mix_exhaust.inlet_1.mole_frac_comp[0.0,"CO2"].fix(0.08)
m.fs.mix_exhaust.inlet_1.mole_frac_comp[0.0,"H2O"].fix(0.76)
m.fs.mix_exhaust.inlet_1.temperature.fix(T_FC_ex_out+273.15)
m.fs.mix_exhaust.inlet_1.pressure.fix(101325)

# %%
m.fs.mix_exhaust.inlet_1.display()

# %%
# Second inlet to mix_exhaust : cathode exhaust
m.fs.mix_exhaust.inlet_2.flow_mol.fix(364.95238095238096)
m.fs.mix_exhaust.inlet_2.mole_frac_comp[0.0,:].fix(0.0)
m.fs.mix_exhaust.inlet_2.mole_frac_comp[0.0,"O2"].fix(0.1753653444676409)
m.fs.mix_exhaust.inlet_2.mole_frac_comp[0.0,"N2"].fix(0.824634655532359)
m.fs.mix_exhaust.inlet_2.temperature.fix(T_FC_ex_out+273.15)
m.fs.mix_exhaust.inlet_2.pressure.fix(101325)

# %%
m.fs.mix_exhaust.inlet_2.display()

# %% [markdown]
# ### Burner as Gibbs Reactor

# %%
m.fs.burner = GibbsReactor(default={"dynamic": False,
                                    "property_package": m.fs.thermo_params,
                                    "has_pressure_change": False,
                                    "has_heat_transfer": True})

# %% [markdown]
# ### Point mixer stream to Burner:

# %%
m.fs.stream1 = Arc(source=m.fs.mix_exhaust.outlet,
                  destination=m.fs.burner.inlet)

# %%
TransformationFactory("network.expand_arcs").apply_to(m)

# %%
from idaes.core.util.model_statistics import degrees_of_freedom as dof
dof(m)

# %%
m.fs.burner.heat_duty.fix(0.0)

# %%
from idaes.core.util.model_statistics import degrees_of_freedom as dof
dof(m)

# %%
solver = SolverFactory('ipopt')

# %%
results = solver.solve(m, tee=True)

# %%
print(results)

# %%
m.fs.burner.inlet.display()

# %%
m.fs.burner.outlet.display()

# %% [markdown]
# ### Make another Gibbs Reactor to represent the SOFC

# %%
m.fs.SOFC = GibbsReactor(default={"dynamic": False,
                                  "property_package": m.fs.thermo_params,
                                  "has_pressure_change": False,
                                  "has_heat_transfer": True})
