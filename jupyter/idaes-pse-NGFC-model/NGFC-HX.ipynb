# %%
from pyomo.environ import ConcreteModel, Constraint, Objective, SolverFactory, TransformationFactory, Constraint, Var
from pyomo.network import Arc

# %%
from idaes.core import FlowsheetBlock
from idaes.unit_models import Mixer, HeatExchanger, Separator, GibbsReactor
# Methane combustion ideal package got CH4, H2O, CO, CO2, N2, NH3, O2
import idaes.property_models.activity_coeff_models.methane_combustion_ideal as thermo_props
#import idaes.property_models.activity_coeff_models.methane_combustion_ideal as reaction_props

# %%
from idaes.unit_models.separator import SplittingType
from idaes.unit_models.heat_exchanger import delta_temperature_amtd_callback
from idaes.core.util.model_statistics import degrees_of_freedom as dof

# %%
from idaes.unit_models import Mixer

# %%
m = ConcreteModel()
m.fs = FlowsheetBlock(default={"dynamic": False})
m.fs.thermo_params = thermo_props.MethaneParameterBlock()

# %%
m.fs.HX1 = HeatExchanger(default={"dynamic": False,
                                  "delta_temperature_callback": delta_temperature_amtd_callback,
                                  "shell":{"property_package": m.fs.thermo_params},
                                  "tube":{"property_package": m.fs.thermo_params}})

# %%
m.fs.HX1.tube_inlet.temperature.fix(500)
m.fs.HX1.tube_inlet.fix()
m.fs.HX1.tube_inlet.flow_mol.fix(2.0)

# %%
m.fs.HX1.shell_inlet.fix()
m.fs.HX1.shell_inlet.temperature.fix(800)
m.fs.HX1.shell_inlet.flow_mol.fix(2.0)

# %%
m.fs.HX1.tube_inlet.display()
# Out:
# inlet_2 : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 2.0}
#          : mole_frac_comp : {(0.0, 'CH4'): 0.125, (0.0, 'CO'): 0.125, (0.0, 'CO2'): 0.125, (0.0, 'H2'): 0.125, (0.0, 'H2O'): 0.125, (0.0, 'N2'): 0.125, (0.0, 'NH3'): 0.125, (0.0, 'O2'): 0.125}
#          :       pressure : {0.0: 101325}
#          :    temperature : {0.0: 500}

# %%
m.fs.HX1.area.fix(1)

# %%
m.fs.HX1.overall_heat_transfer_coefficient.unfix()

# %%
#m.fs.HX1.overall_heat_transfer_coefficient[0.0].fix(100)
#m.fs.HX1.exit_temp_constraint = Constraint(expr=m.fs.HX1.shell_outlet.temperature[0] - 600==0 )
m.fs.HX1.shell_outlet.temperature.fix(600)

# %%
dof(m)
# Out:
# 0

# %%
m.fs.HX1.initialize(state_args_1={"flow_mol" : 2.0,
                                  "mole_frac_comp" : {"CH4": 0.125,
                                                      "CO": 0.125,
                                                      "CO2": 0.125,
                                                      "H2": 0.125,
                                                      "H2O": 0.125,
                                                      "N2": 0.125,
                                                      "NH3": 0.125,
                                                      "O2": 0.125,
                                                     },
                                  "pressure" : 101325,
                                  "temperature" : 800},
                    state_args_2={"flow_mol" : 2.0,
                                  "mole_frac_comp" : {"CH4": 0.125,
                                                      "CO": 0.125,
                                                      "CO2": 0.125,
                                                      "H2": 0.125,
                                                      "H2O": 0.125,
                                                      "N2": 0.125,
                                                      "NH3": 0.125,
                                                      "O2": 0.125,
                                                     },
                                  "pressure" : 101325,
                                  "temperature" : 500},
                    duty=15000
                   )
# Out:
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-2603804899f9>", line 25, in <module>
#     duty=15000
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/heat_exchanger.py", line 435, in initialize
#     outlvl=outlvl + 1, optarg=optarg, solver=solver, state_args=state_args_1
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/core/control_volume0d.py", line 1430, in initialize
#     state_args=state_args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.33e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 0.00e+00 2.06e+00  -1.0 4.33e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:10 - Level 4 - idaes.init.fs.HX1.side_1.properties_in - Initialization Step 2 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:10 - Level 4 - idaes.init.fs.HX1.side_1.properties_in - Initialization Step 3 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:10 - Level 4 - idaes.init.fs.HX1.side_1.properties_in - Initialization Step 4 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       42
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       16
#
# Total number of variables............................:       18
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       18
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.40e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 2.91e-11 5.55e-17  -1.0 1.40e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   6.7216445058987667e-15    2.9103830456733704e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   6.7216445058987667e-15    2.9103830456733704e-11
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:10 - Level 4 - idaes.init.fs.HX1.side_1.properties_in - Initialization Step 5 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-2603804899f9>", line 25, in <module>
#     duty=15000
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/heat_exchanger.py", line 435, in initialize
#     outlvl=outlvl + 1, optarg=optarg, solver=solver, state_args=state_args_1
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/core/control_volume0d.py", line 1436, in initialize
#     state_args=state_args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.43e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 0.00e+00 2.06e+00  -1.0 4.43e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:10 - Level 4 - idaes.init.fs.HX1.side_1.properties_out - Initialization Step 2 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_1.properties_out - Initialization Step 3 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_1.properties_out - Initialization Step 4 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       42
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       16
#
# Total number of variables............................:       18
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       18
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.48e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 0.00e+00 5.55e-17  -1.0 1.48e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_1.properties_out - Initialization Step 5 optimal.
# 2020-05-07 11:56:11 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.HX1.side_1.properties_out State Released.
# 2020-05-07 11:56:11 - Level 5 - idaes.init.fs.HX1.side_1.properties_out - Initialization Complete: optimal
# 2020-05-07 11:56:11 - Level 5 - idaes.init.fs.HX1.side_1 - Initialization Complete
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-2603804899f9>", line 25, in <module>
#     duty=15000
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/heat_exchanger.py", line 441, in initialize
#     outlvl=outlvl + 1, optarg=optarg, solver=solver, state_args=state_args_2
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/core/control_volume0d.py", line 1430, in initialize
#     state_args=state_args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.48e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 0.00e+00 2.06e+00  -1.0 4.48e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_2.properties_in - Initialization Step 2 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_2.properties_in - Initialization Step 3 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_2.properties_in - Initialization Step 4 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ...
#     app.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-2603804899f9>", line 25, in <module>
#     duty=15000
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/unit_models/heat_exchanger.py", line 441, in initialize
#     outlvl=outlvl + 1, optarg=optarg, solver=solver, state_args=state_args_2
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/core/control_volume0d.py", line 1436, in initialize
#     state_args=state_args)
#   File "/Users/adlerlabadmin/anaconda3/envs/idaes-env/lib/python3.7/site-packages/idaes/property_models/activity_coeff_models/activity_coeff_prop_pack.py", line 299, in initialize
#     init_log.info(4, "Initialization step 1 skipped")
# Message: 4
# Arguments: ('Initialization step 1 skipped',)
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.48e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 0.00e+00 2.06e+00  -1.0 4.48e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_2.properties_out - Initialization Step 2 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_2.properties_out - Initialization Step 3 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       25
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       17
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_2.properties_out - Initialization Step 4 optimal.
# Ipopt 3.13.2: tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       42
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       16
#
# Total number of variables............................:       18
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       18
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.52e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 0.00e+00 5.55e-17  -1.0 1.52e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-05-07 11:56:11 - Level 4 - idaes.init.fs.HX1.side_2.properties_out - Initialization Step 5 optimal.
# 2020-05-07 11:56:11 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.HX1.side_2.properties_out State Released.
# 2020-05-07 11:56:11 - Level 5 - idaes.init.fs.HX1.side_2.properties_out - Initialization Complete: optimal
# 2020-05-07 11:56:11 - Level 5 - idaes.init.fs.HX1.side_2 - Initialization Complete
# WARNING: Loading a SolverResults object with a warning status into
#     model=fs.HX1;
#         message from solver=Too few degrees of freedom (rethrown)!
# 2020-05-07 11:56:11 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.HX1.side_1.properties_in State Released.
# 2020-05-07 11:56:11 - INFO - idaes.property_models.activity_coeff_models.activity_coeff_prop_pack - fs.HX1.side_2.properties_in State Released.
# 2020-05-07 11:56:11 - Level 5 - idaes.init.fs.HX1 - Initialization Completed, optimal

# %%
solver = SolverFactory('ipopt', halt_on_ampl_error="yes")

# %%
results = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      311
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       87
#
# Total number of variables............................:       98
#                      variables with only lower bounds:        6
#                 variables with lower and upper bounds:       48
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       98
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 5.82e-11 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.8207660913467407e-11    5.8207660913467407e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.8207660913467407e-11    5.8207660913467407e-11
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.

# %%
m.fs.HX1.tube_inlet.display()
# Out:
# inlet_2 : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 2.0}
#          : mole_frac_comp : {(0.0, 'CH4'): 0.125, (0.0, 'CO'): 0.125, (0.0, 'CO2'): 0.125, (0.0, 'H2'): 0.125, (0.0, 'H2O'): 0.125, (0.0, 'N2'): 0.125, (0.0, 'NH3'): 0.125, (0.0, 'O2'): 0.125}
#          :       pressure : {0.0: 101325}
#          :    temperature : {0.0: 500}

# %%
m.fs.HX1.tube_outlet.display()
# Out:
# outlet_2 : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 2.0}
#          : mole_frac_comp : {(0.0, 'CH4'): 0.125, (0.0, 'CO'): 0.125, (0.0, 'CO2'): 0.125, (0.0, 'H2'): 0.125, (0.0, 'H2O'): 0.125, (0.0, 'N2'): 0.125, (0.0, 'NH3'): 0.125, (0.0, 'O2'): 0.125}
#          :       pressure : {0.0: 101325.0}
#          :    temperature : {0.0: 708.878141770179}

# %%
m.fs.HX1.shell_inlet.display()
# Out:
# inlet_1 : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 2.0}
#          : mole_frac_comp : {(0.0, 'CH4'): 0.125, (0.0, 'CO'): 0.125, (0.0, 'CO2'): 0.125, (0.0, 'H2'): 0.125, (0.0, 'H2O'): 0.125, (0.0, 'N2'): 0.125, (0.0, 'NH3'): 0.125, (0.0, 'O2'): 0.125}
#          :       pressure : {0.0: 101325}
#          :    temperature : {0.0: 800}

# %%
m.fs.HX1.shell_outlet.display()
# Out:
# outlet_1 : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 2.0}
#          : mole_frac_comp : {(0.0, 'CH4'): 0.125, (0.0, 'CO'): 0.125, (0.0, 'CO2'): 0.125, (0.0, 'H2'): 0.125, (0.0, 'H2O'): 0.125, (0.0, 'N2'): 0.125, (0.0, 'NH3'): 0.125, (0.0, 'O2'): 0.125}
#          :       pressure : {0.0: 101325.0}
#          :    temperature : {0.0: 600}

# %%
m.fs.HX1.heat_duty.display()
# Out:
# heat_duty : Size=1, Index=fs.time
#     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#     0.0 :  None : 15875.513699999956 :  None : False : False :  Reals

# %%
m.fs.HX1.shell_inlet.display()
# Out:
# inlet_1 : Size=1
#     Key  : Name           : Value
#     None :       flow_mol : {0.0: 2.0}
#          : mole_frac_comp : {(0.0, 'CH4'): 0.125, (0.0, 'CO'): 0.125, (0.0, 'CO2'): 0.125, (0.0, 'H2'): 0.125, (0.0, 'H2O'): 0.125, (0.0, 'N2'): 0.125, (0.0, 'NH3'): 0.125, (0.0, 'O2'): 0.125}
#          :       pressure : {0.0: 101325}
#          :    temperature : {0.0: 800}

# %%
m.fs.HX1.overall_heat_transfer_coefficient.display()
# Out:
# overall_heat_transfer_coefficient : Overall heat transfer coefficient
#     Size=1, Index=fs.time
#     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#     0.0 :     0 : 166.12975456642468 :  None : False : False : PositiveReals

# %%
m.fs.HX1.delta_temperature_in.display()
# Out:
# delta_temperature_in : Temperature difference at the hot inlet end
#     Size=1, Index=fs.time
#     Key : Lower : Value             : Upper : Fixed : Stale : Domain
#     0.0 :  None : 91.12185822982093 :  None : False : False :  Reals

# %%
800-673.8901213224003
# Out:
# 126.10987867759968

# %%
673.8901213224003-500
# Out:
# 173.89012132240032

# %%
673.8901213224003-800
# Out:
# -126.10987867759968

# %%
800-636.1726908969673
# Out:
# 163.8273091030327

# %%
500-636.1726908969673
# Out:
# -136.1726908969673

# %%
m.fs.HX1.shell_outlet.temperature[0]

# %%
m.fs.HX1.delta_temperature_in.display()
# Out:
# delta_temperature_in : Temperature difference at the hot inlet end
#     Size=1, Index=fs.time
#     Key : Lower : Value             : Upper : Fixed : Stale : Domain
#     0.0 :  None : 91.12185822982093 :  None : False : False :  Reals

# %%
m.fs.HX1.delta_temperature_out.display()
# Out:
# delta_temperature_out : Temperature difference at the hot outlet end
#     Size=1, Index=fs.time
#     Key : Lower : Value : Upper : Fixed : Stale : Domain
#     0.0 :  None : 100.0 :  None : False : False :  Reals

# %%
m.fs.HX1.delta_temperature.display()
# Out:
# delta_temperature : Size=1
#     Key : Value
#     0.0 : 95.56092911491046

# %%
m.fs.HX1.heat_duty.display()
# Out:
# heat_duty : Size=1, Index=fs.time
#     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#     0.0 :  None : 15875.513699999956 :  None : False : False :  Reals

# %%
m.fs.HX1.heat_transfer_equation.display()
# Out:
# heat_transfer_equation : Size=1
#     Key : Lower : Body                   : Upper
#     0.0 :   0.0 : -3.747118171304464e-16 :   0.0
